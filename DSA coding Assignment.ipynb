# %%
# 1. Printing Half Pyramid Pattern.

rows=int(input("enter the no.of rows"))
ascii_value=65
for i in range(rows):
  for j in range(i+1):
    alphabet=chr(ascii_value)
    print(alphabet,end=" ")
  
  ascii_value += 1
  print("\n")
# Out:
# enter the no.of rows5
# A
#
# B B
#
# C C C
#
# D D D D
#
# E E E E E

# %%
# 2. Printing Full Pyramid Pattern:

rows = int(input("enter rows"))
for i in range(rows):
  if i%2==0:
    pass
    for j in range(i+1):
      print("*",end="")
    print("\n")
# Out:
# enter rows10
# *
#
# ***
#
# *****
#
# *******
#
# *********

# %%
# 3. Reverse a number entered by the user:

def reverse_digits(num):
  string=str(num)
  string=string[::-1]

  num=int(string)
  return num
  
if __name__ == "__main__":
  num=int(input("Enter the number:"))
  print("Reversed Order is:",reverse_digits(num))
# Out:
# Enter the number:567
# Reversed Order is: 765

# %%
# 4. Find a peak element which is not smaller than its neighbours:

array=[10,20,15,2,23,90,67]
def greater(array):
  for i in range(1,len(array)):
    if array[i]>array[i-1]:
      if array[i]==array[len(array)-1]:
        pass
      elif array[i]>array[i+1]:
        print(array[i])

greater(array)
# Out:
# 20
# 90

# %%
array=[5,10,20,15]
def greater(array):
  for i in range(1,len(array)):
    if array[i]>array[i-1]:
      if array[i]==array[len(array)-1]:
        pass
      elif array[i]>array[i+1]:
        print(array[i])

greater(array)
# Out:
# 20

# %%
# 5. Program to cyclically rotate an array by one:

def rotate(array,n):
  x=array[n-1]
  for i in range(n-1,0,-1):
    array[i]=array[i-1]

  array[0]=x

array=[1,2,3,4,5]
n=len(array)
print("Array is:")
for i in range(0,n):
    print(array[i],end=' ')

rotate(array,n)

print("\nRotated array is:")
for i in range(0,n):
    print(array[i],end=' ')
# Out:
# Array is:
# 1 2 3 4 5
# Rotated array is:
# 5 1 2 3 4

# %%
# 6.Longest Consecutive Subsequence.

def findLongestConseqSubseq(arr,n):
  ans=0
  count=0

  arr.sort()
  v=[]
  v.append(arr[0])

  for i in range(1,n):
    if (arr[i]!=arr[i-1]):
      v.append(arr[i])
    
  for i in range(len(v)):
    if (i>0 and v[i]==v[i-1]+1):
      count+=1

    else:
      count=1

    ans=max(ans,count)

  return ans

arr=[1, 9, 3, 10, 4, 20, 2]
n=len(arr)
print("Length of the Longest contiguous subsequence is",
      findLongestConseqSubseq(arr,n))
# Out:
# Length of the Longest contiguous subsequence is 4

# %%
def findLongestConseqSubseq(arr,n):
  ans=0
  count=0

  arr.sort()
  v=[]
  v.append(arr[0])

  for i in range(1,n):
    if (arr[i]!=arr[i-1]):
      v.append(arr[i])
    
  for i in range(len(v)):
    if (i>0 and v[i]==v[i-1]+1):
      count+=1

    else:
      count=1

    ans=max(ans,count)

  return ans

arr=[36, 41, 56, 35, 44, 33, 34, 92, 43, 32, 42]
n=len(arr)
print("Length of the Longest contiguous subsequence is",
      findLongestConseqSubseq(arr,n))
# Out:
# Length of the Longest contiguous subsequence is 5
